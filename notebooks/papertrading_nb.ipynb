# %%
import sys
sys.path.insert(0, '../')
import logging
logging.basicConfig(level=logging.ERROR)

from datetime import datetime, timedelta, timezone

from cryptotrader.envs.trading import PaperTradingEnvironment, PaperTradingDataFeed
from cryptotrader.agents import apriori
from cryptotrader.exchange_api.poloniex import Poloniex
from cryptotrader.envs.utils import make_balance

from bokeh.io import output_notebook
output_notebook()
# %matplotlib inline
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="600c44aa-23ea-480a-8f8b-b8fc53f84362">Loading BokehJS ...</span>
#     </div>

# %%
# Simulation Params
test_name = 'Paper_trading'
obs_steps = 3 # Observation steps
period = 5 # Observation period
pairs = ["USDT_BTC", "USDT_ETH", "USDT_LTC", "USDT_XRP", "USDT_XMR", "USDT_ETC", "USDT_ZEC", "USDT_DASH"] # Universe
fiat_symbol = 'USDT' # Quote symbol
# init_funds = make_balance(crypto=0.01, fiat=100.0, pairs=pairs) # Initial portfolio
init_funds = {"BTC":'0.120000000',                                         # Manual input
              "ETH":'0.12000000',
              "LTC":'0.00000000',
              "XRP":'0.00000000',
              "XMR":"0.00000000",
              "ETC":"0.00000000",
              "ZEC":"0.00000000",
              "DASH":"0.00000000",
              "USDT":'100.00000000'}
# Email data for reporting
# email = 'email@gmail.com'
# password = 'password'

# %%
# Env setup
tapi = Poloniex()
tapi = PaperTradingDataFeed(tapi, period, pairs, init_funds)

env = PaperTradingEnvironment(period, obs_steps, tapi, fiat_symbol, test_name)

# Email for report generation (Gmail only)
# env.set_email(email, password)

obs = env.reset()

# %%
# Run simulation
agent = apriori.TestAgent(env.get_observation(True).shape)
# agent = apriori.PAMRTrader(sensitivity=0.04, C=2500, variant='PAMR2')
agent.trade(env, verbose=True)
# Out:
# Executing trading with 5 min frequency.
# Initial portfolio value: 1159.452335 fiat units.
#
# Agent Trade Error: IndexError in line 233: index 9 is out of bounds for axis 0 with size 9
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-c29302898f09> in <module>()
#       2 agent = apriori.TestAgent(env.get_observation(True).shape)
#       3 # agent = apriori.PAMRTrader(sensitivity=0.04, C=2500, variant='PAMR2')
# ----> 4 agent.trade(env, verbose=True)
#
# /app/cryptotrader/core.py in trade(self, env, start_step, act_now, timeout, verbose, render, email, save_dir)
#     377             print("\nAgent Trade Error:",
#     378                   type(e).__name__ + ' in line ' + str(e.__traceback__.tb_lineno) + ': ' + str(e))
# --> 379             raise e
#     380
#     381     def make_report(self, env, obs, reward, episode_reward, t0, action_time, next_action, prev_portval, init_portval):
#
# /app/cryptotrader/core.py in trade(self, env, start_step, act_now, timeout, verbose, render, email, save_dir)
#     231             if verbose:
#     232                 msg = self.make_report(env, obs, reward, episode_reward, t0, init_time, env.calc_portfolio_vector(),
# --> 233                                        prev_portval, init_portval)
#     234                 print(msg, end="\r", flush=True)
#     235                 if email and may_report:
#
# /app/cryptotrader/core.py in make_report(self, env, obs, reward, episode_reward, t0, action_time, next_action, prev_portval, init_portval)
#     460                 dac = 100 * float(da[symbol])
#     461                 nac = 100 * float(la[symbol])
# --> 462                 na = 100 * float(next_action[i])
#     463
#     464                 msg += "%-8s:  %5.02f %%    %5.02f %%    %5.02f %%    %5.02f %%\n" % (symbol,
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
# Plot results
env.plot_results();
